# %% [markdown]
# in this notebook, I walk through how to download ACS ses data from CensusData package in python. At the bottom are some questions for next steps. -val

# %% [markdown]
# ## helpful documentation: https://jtleider.github.io/censusdata/

# %% [markdown]
# #### let's install the CensusData package

# %%
# will need to install every few hours, consider making a covidcrew env. to keep installed packages
# !pip install CensusData
# Out:
# Requirement already satisfied: CensusData in /opt/conda/envs/whw/lib/python3.6/site-packages (1.8)
# Requirement already satisfied: pandas in /opt/conda/envs/whw/lib/python3.6/site-packages (from CensusData) (1.0.5)
# Requirement already satisfied: requests in /opt/conda/envs/whw/lib/python3.6/site-packages (from CensusData) (2.24.0)
# Requirement already satisfied: numpy>=1.13.3 in /opt/conda/envs/whw/lib/python3.6/site-packages (from pandas->CensusData) (1.19.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in /opt/conda/envs/whw/lib/python3.6/site-packages (from pandas->CensusData) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /opt/conda/envs/whw/lib/python3.6/site-packages (from pandas->CensusData) (2020.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/whw/lib/python3.6/site-packages (from requests->CensusData) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/envs/whw/lib/python3.6/site-packages (from requests->CensusData) (1.25.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/envs/whw/lib/python3.6/site-packages (from requests->CensusData) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/envs/whw/lib/python3.6/site-packages (from requests->CensusData) (2.10)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/whw/lib/python3.6/site-packages (from python-dateutil>=2.6.1->pandas->CensusData) (1.15.0)

# %%
import pandas as pd
import censusdata

# %% [markdown]
# #### Let's look at the data and find the information we want to use

# %%
# search keywords to find data we want
censusdata.search('acs5', 2015, 'label', 'income')[160:165]
# Out:
# [('B06010_035E',
#   'B06010. Place of Birth by Individual Income in the Past 12 Months (in 2015 Inflation-Adjusted Dollars) in the United States',
#   'Native; born outside the United States:!!No income'),
#  ('B06010_035M',
#   'B06010. Place of Birth by Individual Income in the Past 12 Months (in 2015 Inflation-Adjusted Dollars) in the United States',
#   'Margin of Error for!!Native; born outside the United States:!!No income'),
#  ('B06010_036E',
#   'B06010. Place of Birth by Individual Income in the Past 12 Months (in 2015 Inflation-Adjusted Dollars) in the United States',
#   'Native; born outside the United States:!!With income:'),
#  ('B06010_036M',
#   'B06010. Place of Birth by Individual Income in the Past 12 Months (in 2015 Inflation-Adjusted Dollars) in the United States',
#   'Margin of Error for!!Native; born outside the United States:!!With income:'),
#  ('B06010_037E',
#   'B06010. Place of Birth by Individual Income in the Past 12 Months (in 2015 Inflation-Adjusted Dollars) in the United States',
#   'Native; born outside the United States:!!With income:!!$1 to $9,999 or loss')]

# %%
# find the state code for MA
censusdata.geographies(censusdata.censusgeo([('state', '*')]), 'acs5', 2015)
# Out:
# {'Alabama': censusgeo((('state', '01'),)),
#  'Alaska': censusgeo((('state', '02'),)),
#  'Arizona': censusgeo((('state', '04'),)),
#  'Arkansas': censusgeo((('state', '05'),)),
#  'California': censusgeo((('state', '06'),)),
#  'Colorado': censusgeo((('state', '08'),)),
#  'Connecticut': censusgeo((('state', '09'),)),
#  'Delaware': censusgeo((('state', '10'),)),
#  'District of Columbia': censusgeo((('state', '11'),)),
#  'Florida': censusgeo((('state', '12'),)),
#  'Georgia': censusgeo((('state', '13'),)),
#  'Hawaii': censusgeo((('state', '15'),)),
#  'Idaho': censusgeo((('state', '16'),)),
#  'Illinois': censusgeo((('state', '17'),)),
#  'Indiana': censusgeo((('state', '18'),)),
#  'Iowa': censusgeo((('state', '19'),)),
#  'Kansas': censusgeo((('state', '20'),)),
#  'Kentucky': censusgeo((('state', '21'),)),
#  'Louisiana': censusgeo((('state', '22'),)),
#  'Maine': censusgeo((('state', '23'),)),
#  'Maryland': censusgeo((('state', '24'),)),
#  'Massachusetts': censusgeo((('state', '25'),)),
#  'Michigan': censusgeo((('state', '26'),)),
#  'Minnesota': censusgeo((('state', '27'),)),
#  'Mississippi': censusgeo((('state', '28'),)),
#  'Missouri': censusgeo((('state', '29'),)),
#  'Montana': censusgeo((('state', '30'),)),
#  'Nebraska': censusgeo((('state', '31'),)),
#  'Nevada': censusgeo((('state', '32'),)),
#  'New Hampshire': censusgeo((('state', '33'),)),
#  'New Jersey': censusgeo((('state', '34'),)),
#  'New Mexico': censusgeo((('state', '35'),)),
#  'New York': censusgeo((('state', '36'),)),
#  'North Carolina': censusgeo((('state', '37'),)),
#  'North Dakota': censusgeo((('state', '38'),)),
#  'Ohio': censusgeo((('state', '39'),)),
#  'Oklahoma': censusgeo((('state', '40'),)),
#  'Oregon': censusgeo((('state', '41'),)),
#  'Pennsylvania': censusgeo((('state', '42'),)),
#  'Rhode Island': censusgeo((('state', '44'),)),
#  'South Carolina': censusgeo((('state', '45'),)),
#  'South Dakota': censusgeo((('state', '46'),)),
#  'Tennessee': censusgeo((('state', '47'),)),
#  'Texas': censusgeo((('state', '48'),)),
#  'Utah': censusgeo((('state', '49'),)),
#  'Vermont': censusgeo((('state', '50'),)),
#  'Virginia': censusgeo((('state', '51'),)),
#  'Washington': censusgeo((('state', '53'),)),
#  'West Virginia': censusgeo((('state', '54'),)),
#  'Wisconsin': censusgeo((('state', '55'),)),
#  'Wyoming': censusgeo((('state', '56'),)),
#  'Puerto Rico': censusgeo((('state', '72'),))}

# %%
# find the city code for cities in MA
censusdata.geographies(censusdata.censusgeo([('state','25'),('place', '*')]), 'acs5', 2015)
# Out:
# {'Abington CDP, Massachusetts': censusgeo((('state', '25'), ('place', '00135'))),
#  'Acushnet Center CDP, Massachusetts': censusgeo((('state', '25'), ('place', '00530'))),
#  'Adams CDP, Massachusetts': censusgeo((('state', '25'), ('place', '00590'))),
#  'Agawam Town city, Massachusetts': censusgeo((('state', '25'), ('place', '00840'))),
#  'Amesbury Town city, Massachusetts': censusgeo((('state', '25'), ('place', '01260'))),
#  'Amherst Center CDP, Massachusetts': censusgeo((('state', '25'), ('place', '01360'))),
#  'Andover CDP, Massachusetts': censusgeo((('state', '25'), ('place', '01430'))),
#  'Arlington CDP, Massachusetts': censusgeo((('state', '25'), ('place', '01640'))),
#  'Athol CDP, Massachusetts': censusgeo((('state', '25'), ('place', '02515'))),
#  'Attleboro city, Massachusetts': censusgeo((('state', '25'), ('place', '02690'))),
#  'Ayer CDP, Massachusetts': censusgeo((('state', '25'), ('place', '03040'))),
#  'Baldwinville CDP, Massachusetts': censusgeo((('state', '25'), ('place', '03355'))),
#  'Barnstable Town city, Massachusetts': censusgeo((('state', '25'), ('place', '03690'))),
#  'Barre CDP, Massachusetts': censusgeo((('state', '25'), ('place', '03705'))),
#  'Belchertown CDP, Massachusetts': censusgeo((('state', '25'), ('place', '04790'))),
#  'Bellingham CDP, Massachusetts': censusgeo((('state', '25'), ('place', '04965'))),
#  'Belmont CDP, Massachusetts': censusgeo((('state', '25'), ('place', '05105'))),
#  'Beverly city, Massachusetts': censusgeo((('state', '25'), ('place', '05595'))),
#  'Blandford CDP, Massachusetts': censusgeo((('state', '25'), ('place', '06050'))),
#  'Bliss Corner CDP, Massachusetts': censusgeo((('state', '25'), ('place', '06170'))),
#  'Boston city, Massachusetts': censusgeo((('state', '25'), ('place', '07000'))),
#  'Bourne CDP, Massachusetts': censusgeo((('state', '25'), ('place', '07140'))),
#  'Boxford CDP, Massachusetts': censusgeo((('state', '25'), ('place', '07385'))),
#  'Braintree Town city, Massachusetts': censusgeo((('state', '25'), ('place', '07740'))),
#  'Brewster CDP, Massachusetts': censusgeo((('state', '25'), ('place', '07945'))),
#  'Bridgewater CDP, Massachusetts': censusgeo((('state', '25'), ('place', '08050'))),
#  'Brockton city, Massachusetts': censusgeo((('state', '25'), ('place', '09000'))),
#  'Brookfield CDP, Massachusetts': censusgeo((('state', '25'), ('place', '09070'))),
#  'Brookline CDP, Massachusetts': censusgeo((('state', '25'), ('place', '09210'))),
#  'Burlington CDP, Massachusetts': censusgeo((('state', '25'), ('place', '09875'))),
#  'Buzzards Bay CDP, Massachusetts': censusgeo((('state', '25'), ('place', '10015'))),
#  'Cambridge city, Massachusetts': censusgeo((('state', '25'), ('place', '11000'))),
#  'Chatham CDP, Massachusetts': censusgeo((('state', '25'), ('place', '12960'))),
#  'Chelsea city, Massachusetts': censusgeo((('state', '25'), ('place', '13205'))),
#  'Cheshire CDP, Massachusetts': censusgeo((('state', '25'), ('place', '13310'))),
#  'Chester CDP, Massachusetts': censusgeo((('state', '25'), ('place', '13450'))),
#  'Chicopee city, Massachusetts': censusgeo((('state', '25'), ('place', '13660'))),
#  'Clinton CDP, Massachusetts': censusgeo((('state', '25'), ('place', '14430'))),
#  'Cochituate CDP, Massachusetts': censusgeo((('state', '25'), ('place', '14570'))),
#  'Cordaville CDP, Massachusetts': censusgeo((('state', '25'), ('place', '15340'))),
#  'Danvers CDP, Massachusetts': censusgeo((('state', '25'), ('place', '16285'))),
#  'Dedham CDP, Massachusetts': censusgeo((('state', '25'), ('place', '16530'))),
#  'Deerfield CDP, Massachusetts': censusgeo((('state', '25'), ('place', '16635'))),
#  'Dennis CDP, Massachusetts': censusgeo((('state', '25'), ('place', '16740'))),
#  'Dennis Port CDP, Massachusetts': censusgeo((('state', '25'), ('place', '16810'))),
#  'Devens CDP, Massachusetts': censusgeo((('state', '25'), ('place', '16840'))),
#  'Dover CDP, Massachusetts': censusgeo((('state', '25'), ('place', '17370'))),
#  'Duxbury CDP, Massachusetts': censusgeo((('state', '25'), ('place', '17860'))),
#  'East Brookfield CDP, Massachusetts': censusgeo((('state', '25'), ('place', '18595'))),
#  'East Dennis CDP, Massachusetts': censusgeo((('state', '25'), ('place', '18840'))),
#  'East Douglas CDP, Massachusetts': censusgeo((('state', '25'), ('place', '18875'))),
#  'East Falmouth CDP, Massachusetts': censusgeo((('state', '25'), ('place', '18980'))),
#  'Easthampton Town city, Massachusetts': censusgeo((('state', '25'), ('place', '19370'))),
#  'East Harwich CDP, Massachusetts': censusgeo((('state', '25'), ('place', '19400'))),
#  'East Pepperell CDP, Massachusetts': censusgeo((('state', '25'), ('place', '20310'))),
#  'East Sandwich CDP, Massachusetts': censusgeo((('state', '25'), ('place', '20380'))),
#  'Edgartown CDP, Massachusetts': censusgeo((('state', '25'), ('place', '21115'))),
#  'Essex CDP, Massachusetts': censusgeo((('state', '25'), ('place', '21815'))),
#  'Everett city, Massachusetts': censusgeo((('state', '25'), ('place', '21990'))),
#  'Fall River city, Massachusetts': censusgeo((('state', '25'), ('place', '23000'))),
#  'Falmouth CDP, Massachusetts': censusgeo((('state', '25'), ('place', '23070'))),
#  'Fiskdale CDP, Massachusetts': censusgeo((('state', '25'), ('place', '23840'))),
#  'Fitchburg city, Massachusetts': censusgeo((('state', '25'), ('place', '23875'))),
#  'Forestdale CDP, Massachusetts': censusgeo((('state', '25'), ('place', '24190'))),
#  'Foxborough CDP, Massachusetts': censusgeo((('state', '25'), ('place', '24855'))),
#  'Framingham CDP, Massachusetts': censusgeo((('state', '25'), ('place', '24960'))),
#  'Franklin Town city, Massachusetts': censusgeo((('state', '25'), ('place', '25172'))),
#  'Gardner city, Massachusetts': censusgeo((('state', '25'), ('place', '25485'))),
#  'Gloucester city, Massachusetts': censusgeo((('state', '25'), ('place', '26150'))),
#  'Granby CDP, Massachusetts': censusgeo((('state', '25'), ('place', '26500'))),
#  'Great Barrington CDP, Massachusetts': censusgeo((('state', '25'), ('place', '26780'))),
#  'Greenfield Town city, Massachusetts': censusgeo((('state', '25'), ('place', '27100'))),
#  'Green Harbor-Cedar Crest CDP, Massachusetts': censusgeo((('state', '25'), ('place', '27147'))),
#  'Groton CDP, Massachusetts': censusgeo((('state', '25'), ('place', '27445'))),
#  'Hanscom AFB CDP, Massachusetts': censusgeo((('state', '25'), ('place', '28425'))),
#  'Hanson CDP, Massachusetts': censusgeo((('state', '25'), ('place', '28460'))),
#  'Harwich Center CDP, Massachusetts': censusgeo((('state', '25'), ('place', '29055'))),
#  'Harwich Port CDP, Massachusetts': censusgeo((('state', '25'), ('place', '29090'))),
#  'Hatfield CDP, Massachusetts': censusgeo((('state', '25'), ('place', '29230'))),
#  'Haverhill city, Massachusetts': censusgeo((('state', '25'), ('place', '29405'))),
#  'Hingham CDP, Massachusetts': censusgeo((('state', '25'), ('place', '30175'))),
#  'Holbrook CDP, Massachusetts': censusgeo((('state', '25'), ('place', '30420'))),
#  'Holland CDP, Massachusetts': censusgeo((('state', '25'), ('place', '30630'))),
#  'Holyoke city, Massachusetts': censusgeo((('state', '25'), ('place', '30840'))),
#  'Hopedale CDP, Massachusetts': censusgeo((('state', '25'), ('place', '30980'))),
#  'Hopkinton CDP, Massachusetts': censusgeo((('state', '25'), ('place', '31050'))),
#  'Housatonic CDP, Massachusetts': censusgeo((('state', '25'), ('place', '31295'))),
#  'Hudson CDP, Massachusetts': censusgeo((('state', '25'), ('place', '31575'))),
#  'Hull CDP, Massachusetts': censusgeo((('state', '25'), ('place', '31680'))),
#  'Huntington CDP, Massachusetts': censusgeo((('state', '25'), ('place', '31750'))),
#  'Ipswich CDP, Massachusetts': censusgeo((('state', '25'), ('place', '32275'))),
#  'Kingston CDP, Massachusetts': censusgeo((('state', '25'), ('place', '33185'))),
#  'Lawrence city, Massachusetts': censusgeo((('state', '25'), ('place', '34550'))),
#  'Lee CDP, Massachusetts': censusgeo((('state', '25'), ('place', '34620'))),
#  'Lenox CDP, Massachusetts': censusgeo((('state', '25'), ('place', '34935'))),
#  'Leominster city, Massachusetts': censusgeo((('state', '25'), ('place', '35075'))),
#  'Lexington CDP, Massachusetts': censusgeo((('state', '25'), ('place', '35250'))),
#  'Littleton Common CDP, Massachusetts': censusgeo((('state', '25'), ('place', '36020'))),
#  'Longmeadow CDP, Massachusetts': censusgeo((('state', '25'), ('place', '36335'))),
#  'Lowell city, Massachusetts': censusgeo((('state', '25'), ('place', '37000'))),
#  'Lunenburg CDP, Massachusetts': censusgeo((('state', '25'), ('place', '37385'))),
#  'Lynn city, Massachusetts': censusgeo((('state', '25'), ('place', '37490'))),
#  'Lynnfield CDP, Massachusetts': censusgeo((('state', '25'), ('place', '37595'))),
#  'Madaket CDP, Massachusetts': censusgeo((('state', '25'), ('place', '37735'))),
#  'Malden city, Massachusetts': censusgeo((('state', '25'), ('place', '37875'))),
#  'Mansfield Center CDP, Massachusetts': censusgeo((('state', '25'), ('place', '38230'))),
#  'Marblehead CDP, Massachusetts': censusgeo((('state', '25'), ('place', '38435'))),
#  'Marion Center CDP, Massachusetts': censusgeo((('state', '25'), ('place', '38575'))),
#  'Marlborough city, Massachusetts': censusgeo((('state', '25'), ('place', '38715'))),
#  'Marshfield CDP, Massachusetts': censusgeo((('state', '25'), ('place', '38820'))),
#  'Marshfield Hills CDP, Massachusetts': censusgeo((('state', '25'), ('place', '38960'))),
#  'Mashpee Neck CDP, Massachusetts': censusgeo((('state', '25'), ('place', '39152'))),
#  'Mattapoisett Center CDP, Massachusetts': censusgeo((('state', '25'), ('place', '39485'))),
#  'Maynard CDP, Massachusetts': censusgeo((('state', '25'), ('place', '39660'))),
#  'Medfield CDP, Massachusetts': censusgeo((('state', '25'), ('place', '39730'))),
#  'Medford city, Massachusetts': censusgeo((('state', '25'), ('place', '39835'))),
#  'Melrose city, Massachusetts': censusgeo((('state', '25'), ('place', '40115'))),
#  'Methuen Town city, Massachusetts': censusgeo((('state', '25'), ('place', '40710'))),
#  'Middleborough Center CDP, Massachusetts': censusgeo((('state', '25'), ('place', '40885'))),
#  'Milford CDP, Massachusetts': censusgeo((('state', '25'), ('place', '41200'))),
#  'Millers Falls CDP, Massachusetts': censusgeo((('state', '25'), ('place', '41410'))),
#  'Millis-Clicquot CDP, Massachusetts': censusgeo((('state', '25'), ('place', '41532'))),
#  'Milton CDP, Massachusetts': censusgeo((('state', '25'), ('place', '41725'))),
#  'Monomoscoy Island CDP, Massachusetts': censusgeo((('state', '25'), ('place', '41960'))),
#  'Monson Center CDP, Massachusetts': censusgeo((('state', '25'), ('place', '42180'))),
#  'Monument Beach CDP, Massachusetts': censusgeo((('state', '25'), ('place', '42670'))),
#  'Nahant CDP, Massachusetts': censusgeo((('state', '25'), ('place', '43615'))),
#  'Nantucket CDP, Massachusetts': censusgeo((('state', '25'), ('place', '43755'))),
#  'Needham CDP, Massachusetts': censusgeo((('state', '25'), ('place', '44140'))),
#  'New Bedford city, Massachusetts': censusgeo((('state', '25'), ('place', '45000'))),
#  'Newburyport city, Massachusetts': censusgeo((('state', '25'), ('place', '45245'))),
#  'New Seabury CDP, Massachusetts': censusgeo((('state', '25'), ('place', '45500'))),
#  'Newton city, Massachusetts': censusgeo((('state', '25'), ('place', '45560'))),
#  'North Adams city, Massachusetts': censusgeo((('state', '25'), ('place', '46225'))),
#  'North Amherst CDP, Massachusetts': censusgeo((('state', '25'), ('place', '46295'))),
#  'Northampton city, Massachusetts': censusgeo((('state', '25'), ('place', '46330'))),
#  'Northborough CDP, Massachusetts': censusgeo((('state', '25'), ('place', '46785'))),
#  'North Brookfield CDP, Massachusetts': censusgeo((('state', '25'), ('place', '47100'))),
#  'North Eastham CDP, Massachusetts': censusgeo((('state', '25'), ('place', '47590'))),
#  'North Falmouth CDP, Massachusetts': censusgeo((('state', '25'), ('place', '47730'))),
#  'Northfield CDP, Massachusetts': censusgeo((('state', '25'), ('place', '47800'))),
#  'North Lakeville CDP, Massachusetts': censusgeo((('state', '25'), ('place', '48220'))),
#  'North Pembroke CDP, Massachusetts': censusgeo((('state', '25'), ('place', '48710'))),
#  'North Plymouth CDP, Massachusetts': censusgeo((('state', '25'), ('place', '48780'))),
#  'North Scituate CDP, Massachusetts': censusgeo((('state', '25'), ('place', '49165'))),
#  'North Seekonk CDP, Massachusetts': censusgeo((('state', '25'), ('place', '49200'))),
#  'Northwest Harwich CDP, Massachusetts': censusgeo((('state', '25'), ('place', '49700'))),
#  'North Westport CDP, Massachusetts': censusgeo((('state', '25'), ('place', '49710'))),
#  'Norton Center CDP, Massachusetts': censusgeo((('state', '25'), ('place', '50005'))),
#  'Norwood CDP, Massachusetts': censusgeo((('state', '25'), ('place', '50285'))),
#  'Ocean Bluff-Brant Rock CDP, Massachusetts': censusgeo((('state', '25'), ('place', '50862'))),
#  'Ocean Grove CDP, Massachusetts': censusgeo((('state', '25'), ('place', '50880'))),
#  'Onset CDP, Massachusetts': censusgeo((('state', '25'), ('place', '51160'))),
#  'Orange CDP, Massachusetts': censusgeo((('state', '25'), ('place', '51230'))),
#  'Orleans CDP, Massachusetts': censusgeo((('state', '25'), ('place', '51405'))),
#  'Oxford CDP, Massachusetts': censusgeo((('state', '25'), ('place', '51790'))),
#  'Palmer Town city, Massachusetts': censusgeo((('state', '25'), ('place', '52144'))),
#  'Peabody city, Massachusetts': censusgeo((('state', '25'), ('place', '52490'))),
#  'Pepperell CDP, Massachusetts': censusgeo((('state', '25'), ('place', '52770'))),
#  'Petersham CDP, Massachusetts': censusgeo((('state', '25'), ('place', '53085'))),
#  'Pinehurst CDP, Massachusetts': censusgeo((('state', '25'), ('place', '53680'))),
#  'Pittsfield city, Massachusetts': censusgeo((('state', '25'), ('place', '53960'))),
#  'Plymouth CDP, Massachusetts': censusgeo((('state', '25'), ('place', '54275'))),
#  'Pocasset CDP, Massachusetts': censusgeo((('state', '25'), ('place', '54450'))),
#  'Popponesset CDP, Massachusetts': censusgeo((('state', '25'), ('place', '55070'))),
#  'Popponesset Island CDP, Massachusetts': censusgeo((('state', '25'), ('place', '55090'))),
#  'Provincetown CDP, Massachusetts': censusgeo((('state', '25'), ('place', '55535'))),
#  'Quincy city, Massachusetts': censusgeo((('state', '25'), ('place', '55745'))),
#  'Randolph CDP, Massachusetts': censusgeo((('state', '25'), ('place', '55990'))),
#  'Raynham Center CDP, Massachusetts': censusgeo((('state', '25'), ('place', '56095'))),
#  'Reading CDP, Massachusetts': censusgeo((('state', '25'), ('place', '56165'))),
#  'Revere city, Massachusetts': censusgeo((('state', '25'), ('place', '56585'))),
#  'Rockport CDP, Massachusetts': censusgeo((('state', '25'), ('place', '57845'))),
#  'Rowley CDP, Massachusetts': censusgeo((('state', '25'), ('place', '58370'))),
#  'Russell CDP, Massachusetts': censusgeo((('state', '25'), ('place', '58615'))),
#  'Rutland CDP, Massachusetts': censusgeo((('state', '25'), ('place', '58790'))),
#  'Sagamore CDP, Massachusetts': censusgeo((('state', '25'), ('place', '58965'))),
#  'Salem city, Massachusetts': censusgeo((('state', '25'), ('place', '59105'))),
#  'Salisbury CDP, Massachusetts': censusgeo((('state', '25'), ('place', '59210'))),
#  'Sandwich CDP, Massachusetts': censusgeo((('state', '25'), ('place', '59700'))),
#  'Saugus CDP, Massachusetts': censusgeo((('state', '25'), ('place', '60050'))),
#  'Scituate CDP, Massachusetts': censusgeo((('state', '25'), ('place', '60295'))),
#  'Seabrook CDP, Massachusetts': censusgeo((('state', '25'), ('place', '60505'))),
#  'Seconsett Island CDP, Massachusetts': censusgeo((('state', '25'), ('place', '60627'))),
#  'Sharon CDP, Massachusetts': censusgeo((('state', '25'), ('place', '60820'))),
#  'Shelburne Falls CDP, Massachusetts': censusgeo((('state', '25'), ('place', '61205'))),
#  'Shirley CDP, Massachusetts': censusgeo((('state', '25'), ('place', '61555'))),
#  'Siasconset CDP, Massachusetts': censusgeo((('state', '25'), ('place', '61940'))),
#  'Smith Mills CDP, Massachusetts': censusgeo((('state', '25'), ('place', '62300'))),
#  'Somerset CDP, Massachusetts': censusgeo((('state', '25'), ('place', '62465'))),
#  'Somerville city, Massachusetts': censusgeo((('state', '25'), ('place', '62535'))),
#  'South Amherst CDP, Massachusetts': censusgeo((('state', '25'), ('place', '62675'))),
#  'South Ashburnham CDP, Massachusetts': censusgeo((('state', '25'), ('place', '62780'))),
#  'Southbridge Town city, Massachusetts': censusgeo((('state', '25'), ('place', '63345'))),
#  'South Deerfield CDP, Massachusetts': censusgeo((('state', '25'), ('place', '63620'))),
#  'South Dennis CDP, Massachusetts': censusgeo((('state', '25'), ('place', '63655'))),
#  'South Duxbury CDP, Massachusetts': censusgeo((('state', '25'), ('place', '63690'))),
#  'Southfield CDP, Massachusetts': censusgeo((('state', '25'), ('place', '63840'))),
#  'South Lancaster CDP, Massachusetts': censusgeo((('state', '25'), ('place', '64460'))),
#  'South Yarmouth CDP, Massachusetts': censusgeo((('state', '25'), ('place', '66035'))),
#  'Spencer CDP, Massachusetts': censusgeo((('state', '25'), ('place', '66070'))),
#  'Springfield city, Massachusetts': censusgeo((('state', '25'), ('place', '67000'))),
#  'Stoneham CDP, Massachusetts': censusgeo((('state', '25'), ('place', '67700'))),
#  'Sturbridge CDP, Massachusetts': censusgeo((('state', '25'), ('place', '68120'))),
#  'Swampscott CDP, Massachusetts': censusgeo((('state', '25'), ('place', '68680'))),
#  'Taunton city, Massachusetts': censusgeo((('state', '25'), ('place', '69170'))),
#  'Teaticket CDP, Massachusetts': censusgeo((('state', '25'), ('place', '69205'))),
#  'The Pinehills CDP, Massachusetts': censusgeo((('state', '25'), ('place', '69585'))),
#  'Topsfield CDP, Massachusetts': censusgeo((('state', '25'), ('place', '70115'))),
#  'Townsend CDP, Massachusetts': censusgeo((('state', '25'), ('place', '70325'))),
#  'Turners Falls CDP, Massachusetts': censusgeo((('state', '25'), ('place', '70815'))),
#  'Upton CDP, Massachusetts': censusgeo((('state', '25'), ('place', '71445'))),
#  'Vineyard Haven CDP, Massachusetts': censusgeo((('state', '25'), ('place', '71970'))),
#  'Wakefield CDP, Massachusetts': censusgeo((('state', '25'), ('place', '72250'))),
#  'Walpole CDP, Massachusetts': censusgeo((('state', '25'), ('place', '72460'))),
#  'Waltham city, Massachusetts': censusgeo((('state', '25'), ('place', '72600'))),
#  'Ware CDP, Massachusetts': censusgeo((('state', '25'), ('place', '72845'))),
#  'Wareham Center CDP, Massachusetts': censusgeo((('state', '25'), ('place', '73020'))),
#  'Warren CDP, Massachusetts': censusgeo((('state', '25'), ('place', '73055'))),
#  'Watertown Town city, Massachusetts': censusgeo((('state', '25'), ('place', '73440'))),
#  'Webster CDP, Massachusetts': censusgeo((('state', '25'), ('place', '73930'))),
#  'Wellesley CDP, Massachusetts': censusgeo((('state', '25'), ('place', '74210'))),
#  'Westborough CDP, Massachusetts': censusgeo((('state', '25'), ('place', '75050'))),
#  'West Brookfield CDP, Massachusetts': censusgeo((('state', '25'), ('place', '75365'))),
#  'West Chatham CDP, Massachusetts': censusgeo((('state', '25'), ('place', '75505'))),
#  'West Concord CDP, Massachusetts': censusgeo((('state', '25'), ('place', '75680'))),
#  'West Dennis CDP, Massachusetts': censusgeo((('state', '25'), ('place', '75820'))),
#  'West Falmouth CDP, Massachusetts': censusgeo((('state', '25'), ('place', '75960'))),
#  'Westfield city, Massachusetts': censusgeo((('state', '25'), ('place', '76030'))),
#  'West Springfield Town city, Massachusetts': censusgeo((('state', '25'), ('place', '77890'))),
#  'West Wareham CDP, Massachusetts': censusgeo((('state', '25'), ('place', '78410'))),
#  'West Yarmouth CDP, Massachusetts': censusgeo((('state', '25'), ('place', '78795'))),
#  'Weweantic CDP, Massachusetts': censusgeo((('state', '25'), ('place', '78850'))),
#  'Weymouth Town city, Massachusetts': censusgeo((('state', '25'), ('place', '78972'))),
#  'White Island Shores CDP, Massachusetts': censusgeo((('state', '25'), ('place', '79390'))),
#  'Whitinsville CDP, Massachusetts': censusgeo((('state', '25'), ('place', '79495'))),
#  'Wilbraham CDP, Massachusetts': censusgeo((('state', '25'), ('place', '79705'))),
#  'Williamstown CDP, Massachusetts': censusgeo((('state', '25'), ('place', '79950'))),
#  'Wilmington CDP, Massachusetts': censusgeo((('state', '25'), ('place', '80195'))),
#  'Winchendon CDP, Massachusetts': censusgeo((('state', '25'), ('place', '80370'))),
#  'Winchester CDP, Massachusetts': censusgeo((('state', '25'), ('place', '80545'))),
#  'Winthrop Town city, Massachusetts': censusgeo((('state', '25'), ('place', '81005'))),
#  'Woburn city, Massachusetts': censusgeo((('state', '25'), ('place', '81035'))),
#  'Woods Hole CDP, Massachusetts': censusgeo((('state', '25'), ('place', '81245'))),
#  'Worcester city, Massachusetts': censusgeo((('state', '25'), ('place', '82000'))),
#  'Yarmouth Port CDP, Massachusetts': censusgeo((('state', '25'), ('place', '82595')))}

# %% [markdown]
# #### MA state code: 'Massachusetts': ('state', '25')

# %%
# Download ACS 2011-2015 5-year estimates for city of Boston, MA on population size, median age, and median household income.
censusdata.download('acs5', 2015, censusdata.censusgeo([('state', '25'), ('place', '07000')]), ['B01001_001E', 'B01002_001E', 'B19013_001E'])
censusdata.download('acs5', 2015, censusdata.censusgeo([('state', '25'), ('place', '09210')]), ['B01001_001E', 'B01002_001E', 'B19013_001E'])
# Out:
#                                                     B01001_001E  B01002_001E  \
# Brookline CDP, Massachusetts: Summary level: 16...        59132         34.5
#
#                                                     B19013_001E
# Brookline CDP, Massachusetts: Summary level: 16...        95518

# %% [markdown]
# ### You can download data for the state of MA by city name

# %%
all_cities = censusdata.download('acs5', 2015,
                             censusdata.censusgeo([('state', '25'), ('place', '*')]),
                             ['B01001_001E', 'B01002_001E', 'B19013_001E'])

# %%
all_cities
# the three columns are population size, median age, and median income
# Out:
#                                                     B01001_001E  B01002_001E  \
# Abington CDP, Massachusetts: Summary level: 160...        16112         39.9
# Acushnet Center CDP, Massachusetts: Summary lev...         2859         43.0
# Adams CDP, Massachusetts: Summary level: 160, s...         5475         45.3
# Agawam Town city, Massachusetts: Summary level:...        28688         44.3
# Amesbury Town city, Massachusetts: Summary leve...        16907         43.7
# ...                                                         ...          ...
# Winthrop Town city, Massachusetts: Summary leve...        17962         43.2
# Woburn city, Massachusetts: Summary level: 160,...        39104         39.6
# Woods Hole CDP, Massachusetts: Summary level: 1...          963         48.4
# Worcester city, Massachusetts: Summary level: 1...       183382         33.8
# Yarmouth Port CDP, Massachusetts: Summary level...         4792         61.5
#
#                                                     B19013_001E
# Abington CDP, Massachusetts: Summary level: 160...      80148.0
# Acushnet Center CDP, Massachusetts: Summary lev...      53897.0
# Adams CDP, Massachusetts: Summary level: 160, s...      44926.0
# Agawam Town city, Massachusetts: Summary level:...      61494.0
# Amesbury Town city, Massachusetts: Summary leve...      76558.0
# ...                                                         ...
# Winthrop Town city, Massachusetts: Summary leve...      61919.0
# Woburn city, Massachusetts: Summary level: 160,...      78750.0
# Woods Hole CDP, Massachusetts: Summary level: 1...      70859.0
# Worcester city, Massachusetts: Summary level: 1...      45472.0
# Yarmouth Port CDP, Massachusetts: Summary level...      61715.0
#
# [246 rows x 3 columns]

# %% [markdown]
# # Questions:

# %% [markdown]
# 1. how do we select just the cities grouped by North and South regions from this list?
# 2. How do we access demographic data (race/ethnicity? - the documentation I'm following suggests this data is published in the centennial census data? code: 'sf1'.
